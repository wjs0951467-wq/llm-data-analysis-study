# %%
from pathlib import Path
import sys

print('Python 실행 파일:', sys.executable)
print('현재 작업 폴더:', Path.cwd())
# Out:
# Python 실행 파일: c:\dev\llm-data-analysis-course\.venv\Scripts\python.exe
# 현재 작업 폴더: c:\dev\llm-data-analysis-course\notebooks\ch04

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

PROJECT_ROOT = Path.cwd()

print("PROJECT_ROOT 1 :", PROJECT_ROOT)

PROJECT_ROOT = PROJECT_ROOT.parent
print("PROJECT_ROOT 2 :", PROJECT_ROOT)

if not (PROJECT_ROOT / 'data' / 'raw').exists():
    if (PROJECT_ROOT.parent / 'data' / 'raw').exists():
        ROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / 'data' / 'raw'
sns.set_theme(style='whitegrid')

print('프로젝트 루트:', PROJECT_ROOT)
print('데이터 폴더:', DATA_DIR)
print('데이터 폴더 존재 여부:', DATA_DIR.exists())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5
# ----> 6 PROJECT_ROOT = Path.cwd()
#       7
#       8 print("PROJECT_ROOT 1 :", PROJECT_ROOT)
#       9
#
# NameError: name 'Path' is not defined

# %%
print(type(DATA_DIR))

# df_customers = pd.read_csv(DATA_DIR + "/customers.csv")
df_customers = pd.read_csv(DATA_DIR /"customers.csv")

df_customers.info()
# Out:
# <class 'pathlib.WindowsPath'>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 print(type(DATA_DIR))
#       2
#       3 # df_customers = pd.read_csv(DATA_DIR + "/customers.csv")
# ----> 4 df_customers = pd.read_csv(DATA_DIR /"customers.csv")
#       5
#       6 df_customers.info()
#
# ...
